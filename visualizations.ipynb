# %% [markdown]
# ## Bar Chart of Class Distribution

# %%
import matplotlib.pyplot as plt

class_names = ['Bone Loss', 'Caries', 'Crown', 'Filling', 'Implant', 
               'Missing teeth', 'Periapical lesion', 'Root Canal Treatment', 
               'Root Piece', 'impacted tooth']
counts = [8850, 10667, 11404, 12000, 5880, 8720, 8116, 12000, 6958, 12000]

plt.figure(figsize=(12,6))
bars = plt.bar(class_names, counts, color='skyblue')
plt.xticks(rotation=45, ha='right')
plt.title("Class Distribution Final Dental Assistant Dataset")
plt.ylabel("Number of Instances")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd

df = pd.DataFrame({
    'Class': class_names,
    'Count': counts
})

plt.figure(figsize=(10, 1))
sns.heatmap([df['Count']], annot=True, fmt="d", cmap="Blues", xticklabels=class_names, cbar=False)
plt.yticks([])
plt.title("Heatmap of Class Frequencies")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15828\732969459.py:13: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ## Model Performance on new Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your CSV
df = pd.read_csv("./runs/detect/train2/results.csv")

# Plot precision, recall, mAP50, mAP50-95
plt.figure(figsize=(12,6))
plt.plot(df["epoch"], df["metrics/precision(B)"], label="Precision", marker='o')
plt.plot(df["epoch"], df["metrics/recall(B)"], label="Recall", marker='o')
plt.plot(df["epoch"], df["metrics/mAP50(B)"], label="mAP@50", marker='o')
plt.plot(df["epoch"], df["metrics/mAP50-95(B)"], label="mAP@50-95", marker='o')
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.title("YOLOv8 Validation Metrics over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# Plot training & validation losses
plt.figure(figsize=(12,6))
plt.plot(df["epoch"], df["train/box_loss"], label="Train Box Loss", linestyle="--")
plt.plot(df["epoch"], df["val/box_loss"], label="Val Box Loss", linestyle="--")
plt.plot(df["epoch"], df["train/cls_loss"], label="Train Cls Loss", linestyle="--")
plt.plot(df["epoch"], df["val/cls_loss"], label="Val Cls Loss", linestyle="--")
plt.plot(df["epoch"], df["train/dfl_loss"], label="Train DFL Loss", linestyle="--")
plt.plot(df["epoch"], df["val/dfl_loss"], label="Val DFL Loss", linestyle="--")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("YOLOv8 Training & Validation Losses over Epochs")
plt.legend()
plt.grid(True)
plt.show()
